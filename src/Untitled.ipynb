# %%
# %run data_prep.py
# Out:
# Found 8 file(s)
# Loading: Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv
# Loading: Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv
# Loading: Friday-WorkingHours-Morning.pcap_ISCX.csv
# Loading: Monday-WorkingHours.pcap_ISCX.csv
# Loading: Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv
# Loading: Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv
# Loading: Tuesday-WorkingHours.pcap_ISCX.csv
# Loading: Wednesday-workingHours.pcap_ISCX.csv
# Total rows: 2,830,743
#
# Class distribution:
#   BENIGN  : 2,271,320
#   Attacks : 556,556
# Features selected: 25
#
# Data ready!
#   X shape: (2827876, 25)
#   y shape: (2827876,)
# Saved to data/cleaned_data.csv

# %%
# %run train_model.py
# Out:
# Loading cleaned data...
#   X shape: (2827876, 25)
#   Class balance: {0: 2271320, 1: 556556}
#
# Applying SMOTE to balance classes...
#   After SMOTE: {0: 2271320, 1: 2271320}
#
# Training Random Forest...
#   Training complete.
#
# ========== Model Evaluation ==========
# Accuracy : 0.9982
# ROC-AUC  : 1.0000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       BENIGN       1.00      1.00      1.00    454264
#       ATTACK       1.00      1.00      1.00    454264
#
#     accuracy                           1.00    908528
#    macro avg       1.00      1.00      1.00    908528
# weighted avg       1.00      1.00      1.00    908528
#
# Confusion Matrix:
# [[452867   1397]
#  [   219 454045]]
#
# Top 10 Important Features:
#    1. Destination Port                    0.1129
#    2. Avg Bwd Segment Size                0.1025
#    3. Bwd Packet Length Min               0.0883
#    4. Init_Win_bytes_backward             0.0844
# ...

# %%
# %run dashboard.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File D:\digilians\queensUN\intelligent cybersecurity systems\project\Project\ioc_sentinel\src\dashboard.py:4
#       1 import os
#       2 os.chdir(os.path.dirname(os.path.abspath(__file__)))
# ----> 4 import streamlit as st
#       5 import pandas as pd
#       6 import numpy as np
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
import subprocess
import sys

subprocess.Popen([sys.executable, "-m", "streamlit", "run", "dashboard.py"])
# Out:
# <Popen: returncode: None args: ['C:\\Users\\Alaa Zahra\\miniconda3\\python.e...>

# %%
import pandas as pd

# Load a small sample from your original data
df = pd.read_csv("data/cleaned_data.csv")
sample = df.drop(columns=['Label']).head(100)
sample.to_csv("data/test_sample.csv", index=False)
print("Saved test_sample.csv")
# Out:
# Saved test_sample.csv

# %%
# %run threat_feeds.py
# Out:
# ===== IP Check Results =====
# Fetching threat intelligence feeds...
#   [Emerging Threats] Loaded 467 IPs
#   [Abuse.ch Feodo] Loaded 5 IPs
# Total blacklisted IPs: 481
# Sources: Static Blacklist, Emerging Threats, Abuse.ch Feodo
#   185.220.101.1        🚨 MALICIOUS
#   8.8.8.8              ✅ CLEAN
#   192.168.1.1          ✅ CLEAN
